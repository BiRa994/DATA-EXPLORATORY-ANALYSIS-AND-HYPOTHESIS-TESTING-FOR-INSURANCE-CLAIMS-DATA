# %% [markdown]
# # Insurance Claim Case Study

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import scipy.stats as stats

from warnings import filterwarnings 
filterwarnings('ignore')

# %% [markdown]
# ### 1. Import claims_data.csv and cust_data.csv which is provided to you and combine the two datasets
# ### appropriately to create a 360-degree view of the data. Use the same for the subsequent questions.

# %%
Claims_Data=pd.read_csv(r'claims.csv')
Claims_Data
# Out:
#       claim_id  customer_id      incident_cause  claim_date claim_area  \
# 0     54004764     21868593        Driver error  11/27/2017       Auto
# 1     33985796     75740424               Crime  10/03/2018       Home
# 2     53522022     30308357  Other driver error  02/02/2018       Auto
# 3     13015401     47830476      Natural causes  06/17/2018       Auto
# 4     22890252     19269962               Crime  01/13/2018       Auto
# ...        ...          ...                 ...         ...        ...
# 1095  97727122     35951012  Other driver error  06/11/2017       Auto
# 1096  10247193     14818669      Natural causes  03/14/2018       Auto
# 1097  79807493     85322831  Other driver error  02/09/2018       Auto
# 1098  69299345     73449366        Other causes  03/21/2018       Auto
# 1099  58809728     43020876  Other driver error  06/04/2017       Auto
#
#      police_report           claim_type claim_amount  total_policy_claims  \
# 0               No        Material only        $2980                  1.0
# 1          Unknown        Material only        $2980                  3.0
# 2               No        Material only      $3369.5                  1.0
# 3               No        Material only        $1680                  1.0
# 4               No        Material only        $2680                  1.0
# ...            ...                  ...          ...                  ...
# 1095            No        Material only        $3059                  4.0
# 1096            No        Material only        $1520                  2.0
# 1097            No  Material and injury       $23575                  2.0
# 1098       Unknown  Material and injury       $25120                  1.0
# 1099           Yes  Material and injury       $36685                  3.0
#
#      fraudulent
# 0            No
# 1            No
# 2           Yes
# 3            No
# 4            No
# ...         ...
# 1095        Yes
# 1096         No
# 1097        Yes
# 1098         No
# 1099        Yes
#
# [1100 rows x 10 columns]

# %%
Cust_Data=pd.read_csv(r'cust_demographics.csv')
Cust_Data
# Out:
#        CUST_ID  gender DateOfBirth State       Contact   Segment
# 0     21868593  Female   12-Jan-79    VT  789-916-8172  Platinum
# 1     75740424  Female   13-Jan-70    ME  265-543-1264    Silver
# 2     30308357  Female   11-Mar-84    TN  798-631-4758    Silver
# 3     47830476  Female   01-May-86    MA  413-187-7945    Silver
# 4     19269962    Male   13-May-77    NV  956-871-8691      Gold
# ...        ...     ...         ...   ...           ...       ...
# 1080  79539873  Female   15-Mar-81    ND  459-425-4319  Platinum
# 1081  42364152  Female   07-Jul-96    ID  529-462-1635    Silver
# 1082  19888166    Male   11-Apr-90    WI  712-651-9613      Gold
# 1083  11256802  Female   22-Oct-64    LA  469-345-5617    Silver
# 1084  61575264    Male   12-Jul-95    WY  182-385-1392      Gold
#
# [1085 rows x 6 columns]

# %%
Cust_Claims=pd.merge(left=Claims_Data,right=Cust_Data,left_on='customer_id',right_on='CUST_ID')
Cust_Claims
# Out:
#       claim_id  customer_id      incident_cause  claim_date claim_area  \
# 0     54004764     21868593        Driver error  11/27/2017       Auto
# 1     33985796     75740424               Crime  10/03/2018       Home
# 2     53522022     30308357  Other driver error  02/02/2018       Auto
# 3     63017412     30308357        Driver error  04/04/2018       Auto
# 4     13015401     47830476      Natural causes  06/17/2018       Auto
# ...        ...          ...                 ...         ...        ...
# 1080  62020796     79539873  Other driver error  09/06/2018       Auto
# 1081  63269067     42364152        Other causes  05/09/2017       Home
# 1082  22690595     19888166  Other driver error  05/15/2017       Auto
# 1083  12376894     11256802  Other driver error  04/18/2017       Auto
# 1084  63226031     61575264      Natural causes  03/16/2017       Auto
#
#      police_report     claim_type claim_amount  total_policy_claims  \
# 0               No  Material only        $2980                  1.0
# 1          Unknown  Material only        $2980                  3.0
# 2               No  Material only      $3369.5                  1.0
# 3               No  Material only        $1950                  6.0
# 4               No  Material only        $1680                  1.0
# ...            ...            ...          ...                  ...
# 1080           Yes  Material only        $1770                  1.0
# 1081            No  Material only        $2800                  1.0
# 1082           Yes    Injury only       $33080                  2.0
# 1083            No  Material only        $2840                  4.0
# 1084            No  Material only        $1490                  1.0
#
#      fraudulent   CUST_ID  gender DateOfBirth State       Contact   Segment
# 0            No  21868593  Female   12-Jan-79    VT  789-916-8172  Platinum
# 1            No  75740424  Female   13-Jan-70    ME  265-543-1264    Silver
# 2           Yes  30308357  Female   11-Mar-84    TN  798-631-4758    Silver
# 3            No  30308357  Female   11-Mar-84    TN  798-631-4758    Silver
# 4            No  47830476  Female   01-May-86    MA  413-187-7945    Silver
# ...         ...       ...     ...         ...   ...           ...       ...
# 1080         No  79539873  Female   15-Mar-81    ND  459-425-4319  Platinum
# 1081         No  42364152  Female   07-Jul-96    ID  529-462-1635    Silver
# 1082         No  19888166    Male   11-Apr-90    WI  712-651-9613      Gold
# 1083         No  11256802  Female   22-Oct-64    LA  469-345-5617    Silver
# 1084         No  61575264    Male   12-Jul-95    WY  182-385-1392      Gold
#
# [1085 rows x 16 columns]

# %% [markdown]
# ### 2. Perform a data audit for the datatypes and find out if there are any
# ### mismatch within the current datatypes of the columns and their business significance.

# %%
Cust_Claims.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1085 entries, 0 to 1084
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   claim_id             1085 non-null   int64
#  1   customer_id          1085 non-null   int64
#  2   incident_cause       1085 non-null   object
#  3   claim_date           1085 non-null   object
#  4   claim_area           1085 non-null   object
#  5   police_report        1085 non-null   object
#  6   claim_type           1085 non-null   object
#  7   claim_amount         1020 non-null   object
#  8   total_policy_claims  1075 non-null   float64
#  9   fraudulent           1085 non-null   object
#  10  CUST_ID              1085 non-null   int64
#  11  gender               1085 non-null   object
#  12  DateOfBirth          1085 non-null   object
#  13  State                1085 non-null   object
#  14  Contact              1085 non-null   object
#  15  Segment              1085 non-null   object
# dtypes: float64(1), int64(3), object(12)
# memory usage: 144.1+ KB

# %%
Cust_Claims.claim_date=pd.to_datetime(Cust_Claims.claim_date,format='%m/%d/%Y')

# %%
Cust_Claims.DateOfBirth=pd.to_datetime(Cust_Claims.DateOfBirth,format='%d-%b-%y')

# %%
Cust_Claims.drop(columns=['CUST_ID'],inplace=True)

# %%
Cust_Claims.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1085 entries, 0 to 1084
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   claim_id             1085 non-null   int64
#  1   customer_id          1085 non-null   int64
#  2   incident_cause       1085 non-null   object
#  3   claim_date           1085 non-null   datetime64[ns]
#  4   claim_area           1085 non-null   object
#  5   police_report        1085 non-null   object
#  6   claim_type           1085 non-null   object
#  7   claim_amount         1020 non-null   object
#  8   total_policy_claims  1075 non-null   float64
#  9   fraudulent           1085 non-null   object
#  10  gender               1085 non-null   object
#  11  DateOfBirth          1085 non-null   datetime64[ns]
#  12  State                1085 non-null   object
#  13  Contact              1085 non-null   object
#  14  Segment              1085 non-null   object
# dtypes: datetime64[ns](2), float64(1), int64(2), object(10)
# memory usage: 135.6+ KB

# %% [markdown]
# ### 3. Convert the column claim_amount to numeric. Use the appropriate modules/attributes to remove the  $ sign

# %%
Cust_Claims['claim_amount']=Cust_Claims['claim_amount'].astype('str')
Cust_Claims['claim_amount']=Cust_Claims['claim_amount'].str.strip("$")

# %%
Cust_Claims['claim_amount']=Cust_Claims['claim_amount'].astype('float')

# %%
Cust_Claims.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1085 entries, 0 to 1084
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   claim_id             1085 non-null   int64
#  1   customer_id          1085 non-null   int64
#  2   incident_cause       1085 non-null   object
#  3   claim_date           1085 non-null   datetime64[ns]
#  4   claim_area           1085 non-null   object
#  5   police_report        1085 non-null   object
#  6   claim_type           1085 non-null   object
#  7   claim_amount         1020 non-null   float64
#  8   total_policy_claims  1075 non-null   float64
#  9   fraudulent           1085 non-null   object
#  10  gender               1085 non-null   object
#  11  DateOfBirth          1085 non-null   datetime64[ns]
#  12  State                1085 non-null   object
#  13  Contact              1085 non-null   object
#  14  Segment              1085 non-null   object
# dtypes: datetime64[ns](2), float64(2), int64(2), object(9)
# memory usage: 135.6+ KB

# %%
Cust_Claims.head(3)
# Out:
#    claim_id  customer_id      incident_cause claim_date claim_area  \
# 0  54004764     21868593        Driver error 2017-11-27       Auto
# 1  33985796     75740424               Crime 2018-10-03       Home
# 2  53522022     30308357  Other driver error 2018-02-02       Auto
#
#   police_report     claim_type  claim_amount  total_policy_claims fraudulent  \
# 0            No  Material only        2980.0                  1.0         No
# 1       Unknown  Material only        2980.0                  3.0         No
# 2            No  Material only        3369.5                  1.0        Yes
#
#    gender DateOfBirth State       Contact   Segment
# 0  Female  1979-01-12    VT  789-916-8172  Platinum
# 1  Female  1970-01-13    ME  265-543-1264    Silver
# 2  Female  1984-03-11    TN  798-631-4758    Silver

# %% [markdown]
# ### 4. Of all the injury claims, some of them have gone unreported with the police.
# ### Create an alert flag (1,0) for all such claims.

# %%
Cust_Claims['Alert_Flag']=np.where(Cust_Claims['police_report']=='Yes',1,0)

# %%
Cust_Claims.tail()
# Out:
#       claim_id  customer_id      incident_cause claim_date claim_area  \
# 1080  62020796     79539873  Other driver error 2018-09-06       Auto
# 1081  63269067     42364152        Other causes 2017-05-09       Home
# 1082  22690595     19888166  Other driver error 2017-05-15       Auto
# 1083  12376894     11256802  Other driver error 2017-04-18       Auto
# 1084  63226031     61575264      Natural causes 2017-03-16       Auto
#
#      police_report     claim_type  claim_amount  total_policy_claims  \
# 1080           Yes  Material only        1770.0                  1.0
# 1081            No  Material only        2800.0                  1.0
# 1082           Yes    Injury only       33080.0                  2.0
# 1083            No  Material only        2840.0                  4.0
# 1084            No  Material only        1490.0                  1.0
#
#      fraudulent  gender DateOfBirth State       Contact   Segment  Alert_Flag
# 1080         No  Female  1981-03-15    ND  459-425-4319  Platinum           1
# 1081         No  Female  1996-07-07    ID  529-462-1635    Silver           0
# 1082         No    Male  1990-04-11    WI  712-651-9613      Gold           1
# 1083         No  Female  2064-10-22    LA  469-345-5617    Silver           0
# 1084         No    Male  1995-07-12    WY  182-385-1392      Gold           0

# %% [markdown]
# ### 5. One customer can claim for insurance more than once and in each claim,
# ### multiple categories of claims can be involved. However, customer ID should remain unique.
# ### Retain the most recent observation and delete any duplicated records in the data based on the customer ID column.

# %%
Cust_Claims.drop_duplicates(subset='customer_id',keep='last',inplace=True)

# %%
Cust_Claims.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 6. Check for missing values and impute the missing values with an appropriate value.
# ### (mean for continuous and mode for categorical)

# %%
Cust_Claims.isna().sum()
# Out:
# claim_id                0
# customer_id             0
# incident_cause          0
# claim_date              0
# claim_area              0
# police_report           0
# claim_type              0
# claim_amount           65
# total_policy_claims    10
# fraudulent              0
# gender                  0
# DateOfBirth             0
# State                   0
# Contact                 0
# Segment                 0
# Alert_Flag              0
# dtype: int64

# %%
Mode=Cust_Claims['total_policy_claims'].mode()
Mode
# Out:
# 0    1.0
# Name: total_policy_claims, dtype: float64

# %%
# Categorical Variable

Cust_Claims.total_policy_claims.fillna(value=1.0,inplace=True)

# %%
# Continuous Variable

Cust_Claims.claim_amount.fillna(value=Cust_Claims.claim_amount.mean(),inplace=True)

# %%
Cust_Claims.isna().sum()
# Out:
# claim_id               0
# customer_id            0
# incident_cause         0
# claim_date             0
# claim_area             0
# police_report          0
# claim_type             0
# claim_amount           0
# total_policy_claims    0
# fraudulent             0
# gender                 0
# DateOfBirth            0
# State                  0
# Contact                0
# Segment                0
# Alert_Flag             0
# dtype: int64

# %% [markdown]
# ### 7. Calculate the age of customers in years. Based on the age, categorize the customers according to the below criteria
# ### Children < 18
# ### Youth 18-30
# ### Adult 30-60
# ### Senior > 60

# %%
Cust_Claims['Age']= dt.datetime.now().year - pd.DatetimeIndex(Cust_Claims['DateOfBirth']).year

# %%
# Age is coming Negative
Cust_Claims.head(10)
# Out:
#     claim_id  customer_id  incident_cause claim_date claim_area police_report  \
# 0   54004764     21868593    Driver error 2017-11-27       Auto            No
# 1   33985796     75740424           Crime 2018-10-03       Home       Unknown
# 3   63017412     30308357    Driver error 2018-04-04       Auto            No
# 5   91609100     47830476  Natural causes 2017-04-12       Auto       Unknown
# 7   39219616     19269962    Other causes 2018-09-26       Auto            No
# 9   91475471     21831191    Driver error 2018-02-09       Auto       Unknown
# 10  12878692     18401412    Driver error 2018-01-13       Auto            No
# 11  27026412     73486606  Natural causes 2018-04-10       Auto            No
# 12  43908336     32813689           Crime 2018-02-15       Auto       Unknown
# 13  63246959     33507197           Crime 2017-07-22       Auto            No
#
#              claim_type  claim_amount  total_policy_claims fraudulent  gender  \
# 0         Material only        2980.0                  1.0         No  Female
# 1         Material only        2980.0                  3.0         No  Female
# 3         Material only        1950.0                  6.0         No  Female
# 5         Material only        1440.0                  1.0         No  Female
# 7         Material only        2240.0                  2.0         No    Male
# 9   Material and injury       36810.0                  1.0         No    Male
# 10        Material only        1730.0                  4.0         No    Male
# 11        Material only        1160.0                  3.0         No    Male
# 12        Material only        2620.0                  1.0         No    Male
# 13        Material only        2748.5                  2.0        Yes  Female
#
#    DateOfBirth State       Contact   Segment  Alert_Flag  Age
# 0   1979-01-12    VT  789-916-8172  Platinum           0   43
# 1   1970-01-13    ME  265-543-1264    Silver           0   52
# 3   1984-03-11    TN  798-631-4758    Silver           0   38
# 5   1986-05-01    MA  413-187-7945    Silver           0   36
# 7   1977-05-13    NV  956-871-8691      Gold           0   45
# 9   1977-05-17    NH  419-712-8513      Gold           0   45
# 10  1999-03-02    AR  752-398-2914      Gold           0   23
# 11  1999-10-25    AK  256-968-9172    Silver           0   23
# 12  1993-10-12    ID  142-324-7481    Silver           0   29
# 13  2066-09-09    RI  165-519-4583      Gold           0  -44

# %%
# Changing Date of Birth to Appropriate value

Cust_Claims['DateOfBirth']=np.where(Cust_Claims.DateOfBirth.dt.year.astype(int)>2022,Cust_Claims.DateOfBirth-pd.DateOffset(years=100),Cust_Claims.DateOfBirth)

# %%
Cust_Claims['Age']= dt.datetime.now().year - pd.DatetimeIndex(Cust_Claims['DateOfBirth']).year

# %%
Cust_Claims.head(10)
# Out:
#     claim_id  customer_id  incident_cause claim_date claim_area police_report  \
# 0   54004764     21868593    Driver error 2017-11-27       Auto            No
# 1   33985796     75740424           Crime 2018-10-03       Home       Unknown
# 3   63017412     30308357    Driver error 2018-04-04       Auto            No
# 5   91609100     47830476  Natural causes 2017-04-12       Auto       Unknown
# 7   39219616     19269962    Other causes 2018-09-26       Auto            No
# 9   91475471     21831191    Driver error 2018-02-09       Auto       Unknown
# 10  12878692     18401412    Driver error 2018-01-13       Auto            No
# 11  27026412     73486606  Natural causes 2018-04-10       Auto            No
# 12  43908336     32813689           Crime 2018-02-15       Auto       Unknown
# 13  63246959     33507197           Crime 2017-07-22       Auto            No
#
#              claim_type  claim_amount  total_policy_claims fraudulent  gender  \
# 0         Material only        2980.0                  1.0         No  Female
# 1         Material only        2980.0                  3.0         No  Female
# 3         Material only        1950.0                  6.0         No  Female
# 5         Material only        1440.0                  1.0         No  Female
# 7         Material only        2240.0                  2.0         No    Male
# 9   Material and injury       36810.0                  1.0         No    Male
# 10        Material only        1730.0                  4.0         No    Male
# 11        Material only        1160.0                  3.0         No    Male
# 12        Material only        2620.0                  1.0         No    Male
# 13        Material only        2748.5                  2.0        Yes  Female
#
#    DateOfBirth State       Contact   Segment  Alert_Flag  Age
# 0   1979-01-12    VT  789-916-8172  Platinum           0   43
# 1   1970-01-13    ME  265-543-1264    Silver           0   52
# 3   1984-03-11    TN  798-631-4758    Silver           0   38
# 5   1986-05-01    MA  413-187-7945    Silver           0   36
# 7   1977-05-13    NV  956-871-8691      Gold           0   45
# 9   1977-05-17    NH  419-712-8513      Gold           0   45
# 10  1999-03-02    AR  752-398-2914      Gold           0   23
# 11  1999-10-25    AK  256-968-9172    Silver           0   23
# 12  1993-10-12    ID  142-324-7481    Silver           0   29
# 13  1966-09-09    RI  165-519-4583      Gold           0   56

# %%
Cust_Claims['Age_Group']=np.where(Cust_Claims.Age<18,'Children',np.where((Cust_Claims.Age>=18) & (Cust_Claims.Age<30),'Youth',np.where(Cust_Claims.Age>60,'Senior','Adult')))

# %%
Cust_Claims.head(3)
# Out:
#    claim_id  customer_id incident_cause claim_date claim_area police_report  \
# 0  54004764     21868593   Driver error 2017-11-27       Auto            No
# 1  33985796     75740424          Crime 2018-10-03       Home       Unknown
# 3  63017412     30308357   Driver error 2018-04-04       Auto            No
#
#       claim_type  claim_amount  total_policy_claims fraudulent  gender  \
# 0  Material only        2980.0                  1.0         No  Female
# 1  Material only        2980.0                  3.0         No  Female
# 3  Material only        1950.0                  6.0         No  Female
#
#   DateOfBirth State       Contact   Segment  Alert_Flag  Age Age_Group
# 0  1979-01-12    VT  789-916-8172  Platinum           0   43     Adult
# 1  1970-01-13    ME  265-543-1264    Silver           0   52     Adult
# 3  1984-03-11    TN  798-631-4758    Silver           0   38     Adult

# %% [markdown]
# ### 8. What is the average amount claimed by the customers from various segments?

# %%
Cust_Claims.groupby('Segment')[['claim_amount']].mean()
# Out:
#           claim_amount
# Segment
# Gold      12846.386178
# Platinum  12371.644999
# Silver    12267.146560

# %% [markdown]
# ### 9. What is the total claim amount based on incident cause for all the claims that have been done
# ### at least 20 days prior to 1st of October, 2018.

# %%
from datetime import timedelta

Req_df=pd.DataFrame(Cust_Claims)
End_Date='2018-10-01'
Start_Date=pd.to_datetime(End_Date,format='%Y-%m-%d')- timedelta(days=20)
Incident_Range=(Cust_Claims['claim_date'] >= Start_Date)  & (Cust_Claims['claim_date'] < End_Date)

Req_df=Req_df.loc[Incident_Range]

# %%
Req_df
# Out:
#       claim_id  customer_id      incident_cause claim_date claim_area  \
# 7     39219616     19269962        Other causes 2018-09-26       Auto
# 17    53780662     21240703  Other driver error 2018-09-19       Auto
# 70    43973221     83290720        Driver error 2018-09-26       Auto
# 118   65335959     61810954  Other driver error 2018-09-19       Auto
# 134    4112041     58402401        Other causes 2018-09-12       Auto
# 148   74738945     88449349        Other causes 2018-09-12       Auto
# 162    3589979     14490971               Crime 2018-09-19       Auto
# 193   17871003     98905793  Other driver error 2018-09-19       Auto
# 224    5694962      9677945        Other causes 2018-09-26       Auto
# 305    2581621     18213216        Other causes 2018-09-12       Auto
# 337   89056979     63915259        Other causes 2018-09-26       Home
# 369   31272774     88484857        Other causes 2018-09-19       Auto
# 373    3311108     49481916        Other causes 2018-09-19       Auto
# 376   92399694     92971195  Other driver error 2018-09-26       Home
# 416   87476916     92072156      Natural causes 2018-09-12       Auto
# 445   72555621     58934617        Other causes 2018-09-19       Auto
# 508   81102722     91135917  Other driver error 2018-09-12       Auto
# 528    4257735     28437868  Other driver error 2018-09-26       Auto
# 585   39518274     91180828        Other causes 2018-09-26       Auto
# 615   98163164     69355027               Crime 2018-09-26       Auto
# 683   16347699     51485708               Crime 2018-09-19       Auto
# 764   67588341     11982382  Other driver error 2018-09-19       Auto
# 786   98596005     73876237        Driver error 2018-09-12       Auto
# 801   84632427     90646435        Other causes 2018-09-19       Auto
# 898    4812972     78341228      Natural causes 2018-09-12       Auto
# 975   66301062     30015627      Natural causes 2018-09-12       Auto
# 990   16402994     86164274        Other causes 2018-09-26       Home
# 1009  78804570     69165409        Other causes 2018-09-12       Auto
# 1063  67763980     70708127      Natural causes 2018-09-19       Auto
# 1072  50800999     51669975        Other causes 2018-09-19       Home
#
#      police_report           claim_type  claim_amount  total_policy_claims  \
# 7               No        Material only   2240.000000                  2.0
# 17         Unknown        Material only   1050.000000                  1.0
# 70             Yes  Material and injury  12501.489635                  1.0
# 118        Unknown  Material and injury  36620.000000                  1.0
# 134        Unknown  Material and injury  32710.000000                  1.0
# 148             No        Material only   1080.000000                  1.0
# 162             No        Material only   1880.000000                  4.0
# 193        Unknown        Material only   3139.500000                  3.0
# 224             No        Material only   1520.000000                  1.0
# 305        Unknown  Material and injury  21942.000000                  2.0
# 337            Yes  Material and injury  18530.000000                  1.0
# 369             No        Material only   1900.000000                  1.0
# 373             No        Material only  12501.489635                  2.0
# 376             No        Material only   1140.000000                  1.0
# 416            Yes        Material only   2970.000000                  1.0
# 445            Yes          Injury only  27002.000000                  3.0
# 508             No        Material only   2710.000000                  1.0
# 528             No        Material only   1300.000000                  1.0
# 585        Unknown  Material and injury  28382.000000                  1.0
# 615        Unknown        Material only   2950.000000                  1.0
# 683             No        Material only   2010.000000                  1.0
# 764             No        Material only   1640.000000                  1.0
# 786             No        Material only   2130.000000                  1.0
# 801        Unknown          Injury only  25350.000000                  1.0
# 898        Unknown        Material only   2090.000000                  1.0
# 975            Yes        Material only   2208.000000                  4.0
# 990        Unknown  Material and injury  15760.000000                  1.0
# 1009            No  Material and injury  19390.000000                  1.0
# 1063            No        Material only   1150.000000                  1.0
# 1072           Yes          Injury only  38950.000000                  1.0
#
#      fraudulent  gender DateOfBirth State       Contact   Segment  Alert_Flag  \
# 7            No    Male  1977-05-13    NV  956-871-8691      Gold           0
# 17           No    Male  1963-07-22    MD  473-561-2675    Silver           0
# 70           No    Male  1966-12-06    VA  185-825-6547      Gold           1
# 118          No    Male  1969-05-18    TX  724-493-6179    Silver           0
# 134          No    Male  1979-06-13    KS  134-129-8167    Silver           0
# 148          No    Male  1979-12-17    WA  975-547-5196  Platinum           0
# 162          No  Female  1976-12-10    MN  614-652-1274    Silver           0
# 193         Yes  Female  1993-11-11    ID  823-482-5839  Platinum           0
# 224          No  Female  1987-05-28    SC  849-461-6419  Platinum           0
# 305         Yes    Male  1969-10-06    KY  416-461-9145    Silver           0
# 337          No    Male  1986-05-22    GA  829-157-6239      Gold           1
# 369          No    Male  1960-05-21    UT  189-845-2459    Silver           0
# 373         Yes  Female  1996-03-28    SC  734-137-4865    Silver           0
# 376          No    Male  1975-02-02    DE  892-173-4657      Gold           0
# 416          No  Female  1971-07-28    DE  186-419-2974    Silver           1
# 445         Yes    Male  1990-04-01    CA  157-896-3619  Platinum           1
# 508          No    Male  1986-08-15    NV  697-129-2549  Platinum           0
# 528          No  Female  1968-01-31    NY  398-185-7936  Platinum           0
# 585         Yes  Female  1987-03-17    MI  136-473-6752  Platinum           0
# 615          No  Female  1964-12-17    MO  354-352-3891    Silver           0
# 683          No  Female  1997-04-23    WI  219-562-9756      Gold           0
# 764          No    Male  1988-03-14    OH  439-628-2835      Gold           0
# 786          No  Female  1975-01-27    AL  879-185-4857    Silver           0
# 801          No  Female  1978-12-07    IL  356-975-8315      Gold           0
# 898          No    Male  1986-11-26    SD  475-573-2957      Gold           0
# 975         Yes    Male  1969-09-11    SC  254-523-1634    Silver           1
# 990          No    Male  1962-12-28    SC  843-361-2796  Platinum           0
# 1009         No  Female  1994-10-11    NY  843-784-1843    Silver           0
# 1063        Yes  Female  1975-01-18    TX  189-276-3957  Platinum           0
# 1072         No  Female  1988-02-05    ND  975-463-9541    Silver           1
#
#       Age Age_Group
# 7      45     Adult
# 17     59     Adult
# 70     56     Adult
# 118    53     Adult
# 134    43     Adult
# 148    43     Adult
# 162    46     Adult
# 193    29     Youth
# 224    35     Adult
# 305    53     Adult
# 337    36     Adult
# 369    62    Senior
# 373    26     Youth
# 376    47     Adult
# 416    51     Adult
# 445    32     Adult
# 508    36     Adult
# 528    54     Adult
# 585    35     Adult
# 615    58     Adult
# 683    25     Youth
# 764    34     Adult
# 786    47     Adult
# 801    44     Adult
# 898    36     Adult
# 975    53     Adult
# 990    60     Adult
# 1009   28     Youth
# 1063   47     Adult
# 1072   34     Adult

# %%
Req_df.groupby('incident_cause')[['claim_amount']].sum()
# Out:
#                      claim_amount
# incident_cause
# Crime                 6840.000000
# Driver error         14631.489635
# Natural causes        8418.000000
# Other causes        247257.489635
# Other driver error   47599.500000

# %% [markdown]
# ### 10. How many adults from TX, DE and AK claimed insurance for driver related issues and causes?

# %%
Driver_Issues=Cust_Claims[(Cust_Claims['incident_cause']=='Driver error') | (Cust_Claims['incident_cause']=='Other driver error')]

# %%
Driver_Issues
# Out:
#       claim_id  customer_id      incident_cause claim_date claim_area  \
# 0     54004764     21868593        Driver error 2017-11-27       Auto
# 3     63017412     30308357        Driver error 2018-04-04       Auto
# 9     91475471     21831191        Driver error 2018-02-09       Auto
# 10    12878692     18401412        Driver error 2018-01-13       Auto
# 14    74165873     99103685  Other driver error 2018-01-13       Home
# ...        ...          ...                 ...        ...        ...
# 1075  28084004     82089910        Driver error 2018-06-03       Auto
# 1078  47457836      6756905        Driver error 2017-01-21       Auto
# 1080  62020796     79539873  Other driver error 2018-09-06       Auto
# 1082  22690595     19888166  Other driver error 2017-05-15       Auto
# 1083  12376894     11256802  Other driver error 2017-04-18       Auto
#
#      police_report           claim_type  claim_amount  total_policy_claims  \
# 0               No        Material only        2980.0                  1.0
# 3               No        Material only        1950.0                  6.0
# 9          Unknown  Material and injury       36810.0                  1.0
# 10              No        Material only        1730.0                  4.0
# 14              No        Material only        1495.0                  1.0
# ...            ...                  ...           ...                  ...
# 1075            No        Material only        2780.0                  1.0
# 1078            No        Material only        2320.0                  3.0
# 1080           Yes        Material only        1770.0                  1.0
# 1082           Yes          Injury only       33080.0                  2.0
# 1083            No        Material only        2840.0                  4.0
#
#      fraudulent  gender DateOfBirth State       Contact   Segment  Alert_Flag  \
# 0            No  Female  1979-01-12    VT  789-916-8172  Platinum           0
# 3            No  Female  1984-03-11    TN  798-631-4758    Silver           0
# 9            No    Male  1977-05-17    NH  419-712-8513      Gold           0
# 10           No    Male  1999-03-02    AR  752-398-2914      Gold           0
# 14          Yes  Female  1985-12-30    KY  764-439-9856      Gold           0
# ...         ...     ...         ...   ...           ...       ...         ...
# 1075         No    Male  1973-10-09    FL  257-248-4825    Silver           0
# 1078         No    Male  1997-10-21    NE  924-427-8125    Silver           0
# 1080         No  Female  1981-03-15    ND  459-425-4319  Platinum           1
# 1082         No    Male  1990-04-11    WI  712-651-9613      Gold           1
# 1083         No  Female  1964-10-22    LA  469-345-5617    Silver           0
#
#       Age Age_Group
# 0      43     Adult
# 3      38     Adult
# 9      45     Adult
# 10     23     Youth
# 14     37     Adult
# ...   ...       ...
# 1075   49     Adult
# 1078   25     Youth
# 1080   41     Adult
# 1082   32     Adult
# 1083   58     Adult
#
# [502 rows x 18 columns]

# %%
Driver_State=Driver_Issues[(Driver_Issues['State']=='TX') | (Driver_Issues['State']=='DE') | (Driver_Issues['State']=='AK')]
Driver_State
# Out:
#       claim_id  customer_id      incident_cause claim_date claim_area  \
# 39    70399158     26489135        Driver error 2017-07-01       Auto
# 101    4506676      2632562  Other driver error 2018-05-14       Home
# 103   82144259     92752865        Driver error 2017-04-25       Auto
# 118   65335959     61810954  Other driver error 2018-09-19       Auto
# 147   26716331      3159546  Other driver error 2017-04-25       Auto
# 187   21550521     68772500        Driver error 2018-08-30       Auto
# 188   69348631       154557        Driver error 2018-04-10       Auto
# 199   46572741     82415154  Other driver error 2017-06-11       Auto
# 246    7238381       684748  Other driver error 2018-07-14       Auto
# 263   31574986     11321295        Driver error 2017-02-03       Auto
# 275   34621474     54094880  Other driver error 2017-02-17       Auto
# 277   93028492     62204138        Driver error 2017-10-31       Auto
# 322   87329176     77510822  Other driver error 2018-10-30       Auto
# 355   49252712     76314493  Other driver error 2017-09-14       Home
# 362   34596802     94643289        Driver error 2018-03-14       Auto
# 376   92399694     92971195  Other driver error 2018-09-26       Home
# 381      70068      4669941        Driver error 2017-11-06       Auto
# 389   34691767     84750181  Other driver error 2017-03-09       Home
# 430   22577147     66433138        Driver error 2017-02-23       Auto
# 453   99281527     32464636        Driver error 2017-10-31       Auto
# 524    9124181     19796899  Other driver error 2018-04-04       Auto
# 538   37688454     13687085        Driver error 2018-01-13       Auto
# 551   86096444     65899365        Driver error 2018-07-14       Auto
# 570    9129053     85250389  Other driver error 2017-03-02       Auto
# 574   53831641     15820948        Driver error 2017-09-27       Auto
# 608   78221963     84147585        Driver error 2018-04-10       Auto
# 614   54642809     39959491        Driver error 2018-09-06       Auto
# 650   40283824      9205013        Driver error 2018-06-17       Auto
# 706    6365892     42083451        Driver error 2017-08-31       Auto
# 849   94983900     18282409        Driver error 2017-08-11       Auto
# 926    7136079     29903212        Driver error 2018-06-17       Auto
# 929   21146312     77006226        Driver error 2018-02-15       Auto
# 942   77192370     47415706  Other driver error 2017-08-04       Auto
# 984   17396013     44050095        Driver error 2017-03-22       Auto
# 1016  12612736     74787956        Driver error 2017-09-14       Auto
#
#      police_report           claim_type  claim_amount  total_policy_claims  \
# 39              No        Material only   1110.000000                  1.0
# 101        Unknown        Material only   1400.000000                  1.0
# 103             No          Injury only  12501.489635                  1.0
# 118        Unknown  Material and injury  36620.000000                  1.0
# 147             No          Injury only  17590.000000                  4.0
# 187        Unknown        Material only   2320.000000                  1.0
# 188             No          Injury only  12501.489635                  1.0
# 199             No  Material and injury  15240.000000                  1.0
# 246             No        Material only   2920.000000                  2.0
# 263             No        Material only   2460.000000                  2.0
# 275             No        Material only   1529.500000                  1.0
# 277        Unknown        Material only   2691.000000                  1.0
# 322        Unknown        Material only  12501.489635                  2.0
# 355             No        Material only  12501.489635                  1.0
# 362             No  Material and injury  45287.000000                  1.0
# 376             No        Material only   1140.000000                  1.0
# 381        Unknown          Injury only  29900.000000                  1.0
# 389             No        Material only   2370.000000                  4.0
# 430             No  Material and injury  21447.500000                  2.0
# 453             No        Material only   2323.000000                  1.0
# 524            Yes  Material and injury  24667.500000                  1.0
# 538        Unknown          Injury only  16760.000000                  1.0
# 551             No  Material and injury  34160.000000                  1.0
# 570        Unknown          Injury only  24380.000000                  1.0
# 574            Yes  Material and injury  14570.000000                  1.0
# 608            Yes          Injury only  14430.000000                  4.0
# 614        Unknown        Material only   2720.000000                  1.0
# 650            Yes  Material and injury  23430.000000                  1.0
# 706             No        Material only   2400.000000                  1.0
# 849             No          Injury only  31020.000000                  2.0
# 926             No        Material only   2668.000000                  2.0
# 929             No        Material only   2930.000000                  1.0
# 942        Unknown  Material and injury  18457.500000                  1.0
# 984        Unknown  Material and injury  20458.500000                  1.0
# 1016       Unknown        Material only  12501.489635                  1.0
#
#      fraudulent  gender DateOfBirth State       Contact   Segment  Alert_Flag  \
# 39           No    Male  1994-10-05    DE  654-456-1493  Platinum           0
# 101          No  Female  1985-12-14    AK  498-597-9658  Platinum           0
# 103          No    Male  1986-01-30    AK  143-219-5498    Silver           0
# 118          No    Male  1969-05-18    TX  724-493-6179    Silver           0
# 147          No    Male  1987-10-20    TX  586-129-9752  Platinum           0
# 187          No    Male  1989-11-10    TX  562-259-5432    Silver           0
# 188         Yes  Female  1978-05-23    DE  962-879-1238  Platinum           0
# 199          No  Female  1980-03-08    DE  578-942-1542  Platinum           0
# 246          No    Male  1977-08-03    AK  613-385-2863      Gold           0
# 263          No    Male  1965-11-13    DE  429-596-2169  Platinum           0
# 275         Yes    Male  1984-06-01    DE  568-481-7418    Silver           0
# 277         Yes  Female  1989-12-15    DE  471-934-4961  Platinum           0
# 322          No  Female  1986-03-18    AK  436-934-7156    Silver           0
# 355          No  Female  1961-10-02    DE  389-764-4853    Silver           0
# 362         Yes    Male  1998-04-24    AK  317-612-1425    Silver           0
# 376          No    Male  1975-02-02    DE  892-173-4657      Gold           0
# 381         Yes    Male  1982-08-03    AK  761-462-3458  Platinum           0
# 389          No  Female  1993-05-16    AK  419-431-6251  Platinum           0
# 430         Yes    Male  1978-06-27    TX  752-617-3867      Gold           0
# 453         Yes  Female  1988-08-25    DE  862-247-1496      Gold           0
# 524         Yes  Female  1975-12-17    TX  725-873-8239      Gold           1
# 538          No    Male  1997-11-18    DE  137-146-7356  Platinum           0
# 551          No  Female  1973-07-25    TX  135-971-8567  Platinum           0
# 570         Yes  Female  1967-05-08    TX  827-367-5247  Platinum           0
# 574          No    Male  1964-02-22    TX  583-641-3184    Silver           1
# 608          No    Male  1972-10-18    AK  743-569-4783      Gold           1
# 614          No  Female  1995-04-07    DE  139-742-5417    Silver           0
# 650          No    Male  1963-12-11    DE  239-368-6759  Platinum           1
# 706          No    Male  1967-11-23    AK  689-375-9463  Platinum           0
# 849          No  Female  1973-09-29    AK  326-215-7361      Gold           0
# 926         Yes    Male  1989-12-16    DE  279-918-3268  Platinum           0
# 929          No  Female  1998-02-13    TX  641-295-5498  Platinum           0
# 942         Yes  Female  1961-08-08    DE  179-574-5837      Gold           0
# 984         Yes    Male  1977-06-04    DE  314-298-9257  Platinum           0
# 1016         No    Male  1989-06-19    TX  679-514-5894      Gold           0
#
#       Age Age_Group
# 39     28     Youth
# 101    37     Adult
# 103    36     Adult
# 118    53     Adult
# 147    35     Adult
# 187    33     Adult
# 188    44     Adult
# 199    42     Adult
# 246    45     Adult
# 263    57     Adult
# 275    38     Adult
# 277    33     Adult
# 322    36     Adult
# 355    61    Senior
# 362    24     Youth
# 376    47     Adult
# 381    40     Adult
# 389    29     Youth
# 430    44     Adult
# 453    34     Adult
# 524    47     Adult
# 538    25     Youth
# 551    49     Adult
# 570    55     Adult
# 574    58     Adult
# 608    50     Adult
# 614    27     Youth
# 650    59     Adult
# 706    55     Adult
# 849    49     Adult
# 926    33     Adult
# 929    24     Youth
# 942    61    Senior
# 984    45     Adult
# 1016   33     Adult

# %%
Driver_StateAdult=Driver_State[(Driver_State['Age_Group']=='Adult')]
Driver_StateAdult.groupby('State')[['Age_Group']].count().rename(columns={'Age_Group':'Count'})
# Out:
#        Count
# State
# AK         8
# DE        10
# TX         9

# %% [markdown]
# ### 11. Draw a pie chart between the aggregated value of claim amount based on gender and segment.
# ### Represent the claim amount as a percentage on the pie chart.

# %%
Gender_SegAGG=pd.pivot_table(data=Cust_Claims,values='claim_amount',index='gender',columns='Segment',aggfunc=sum)
Gender_SegAGG
# Out:
# Segment          Gold      Platinum        Silver
# gender
# Female   2.110042e+06  2.369720e+06  1.897302e+06
# Male     2.655967e+06  2.096443e+06  2.347131e+06

# %%
Gender_SegAGG.plot(kind='pie',subplots='true',labels=['Male','Female'],colors=['b','g'],autopct='%1.2f%%',
                   figsize=(20,10),fontsize=15)
plt.title('Claim Amount by Gender and Segment',fontsize=30)

plt.show()

# %% [markdown]
# ### 12. Among males and females, which gender had claimed the most for any type of driver related issues?
# ### E.g. This metric can be compared using a bar chart

# %%
# Driver Related Issues 
Driver_Issues
# Out:
#       claim_id  customer_id      incident_cause claim_date claim_area  \
# 0     54004764     21868593        Driver error 2017-11-27       Auto
# 3     63017412     30308357        Driver error 2018-04-04       Auto
# 9     91475471     21831191        Driver error 2018-02-09       Auto
# 10    12878692     18401412        Driver error 2018-01-13       Auto
# 14    74165873     99103685  Other driver error 2018-01-13       Home
# ...        ...          ...                 ...        ...        ...
# 1075  28084004     82089910        Driver error 2018-06-03       Auto
# 1078  47457836      6756905        Driver error 2017-01-21       Auto
# 1080  62020796     79539873  Other driver error 2018-09-06       Auto
# 1082  22690595     19888166  Other driver error 2017-05-15       Auto
# 1083  12376894     11256802  Other driver error 2017-04-18       Auto
#
#      police_report           claim_type  claim_amount  total_policy_claims  \
# 0               No        Material only        2980.0                  1.0
# 3               No        Material only        1950.0                  6.0
# 9          Unknown  Material and injury       36810.0                  1.0
# 10              No        Material only        1730.0                  4.0
# 14              No        Material only        1495.0                  1.0
# ...            ...                  ...           ...                  ...
# 1075            No        Material only        2780.0                  1.0
# 1078            No        Material only        2320.0                  3.0
# 1080           Yes        Material only        1770.0                  1.0
# 1082           Yes          Injury only       33080.0                  2.0
# 1083            No        Material only        2840.0                  4.0
#
#      fraudulent  gender DateOfBirth State       Contact   Segment  Alert_Flag  \
# 0            No  Female  1979-01-12    VT  789-916-8172  Platinum           0
# 3            No  Female  1984-03-11    TN  798-631-4758    Silver           0
# 9            No    Male  1977-05-17    NH  419-712-8513      Gold           0
# 10           No    Male  1999-03-02    AR  752-398-2914      Gold           0
# 14          Yes  Female  1985-12-30    KY  764-439-9856      Gold           0
# ...         ...     ...         ...   ...           ...       ...         ...
# 1075         No    Male  1973-10-09    FL  257-248-4825    Silver           0
# 1078         No    Male  1997-10-21    NE  924-427-8125    Silver           0
# 1080         No  Female  1981-03-15    ND  459-425-4319  Platinum           1
# 1082         No    Male  1990-04-11    WI  712-651-9613      Gold           1
# 1083         No  Female  1964-10-22    LA  469-345-5617    Silver           0
#
#       Age Age_Group
# 0      43     Adult
# 3      38     Adult
# 9      45     Adult
# 10     23     Youth
# 14     37     Adult
# ...   ...       ...
# 1075   49     Adult
# 1078   25     Youth
# 1080   41     Adult
# 1082   32     Adult
# 1083   58     Adult
#
# [502 rows x 18 columns]

# %%
Gender_Driver=Driver_Issues.groupby('gender')[['claim_amount']].sum()
Gender_Driver
# Out:
#         claim_amount
# gender
# Female  3.136715e+06
# Male    3.975408e+06

# %%
Gender_Driver.plot(kind='bar',figsize=(10,5),title='Gender Wise Claim',fontsize=20)
plt.show()

# %% [markdown]
# ### 13. Which age group had the maximum fraudulent policy claims? Visualize it on a bar chart.

# %%
Fraud_Claims=Cust_Claims.loc[Cust_Claims['fraudulent']=='Yes']

# %%
Fraud_ClaimsGroup=Fraud_Claims.groupby(['Age_Group','fraudulent'])[['fraudulent']].count().rename(columns={'fraudulent':'Count'})
Fraud_ClaimsGroup
# Out:
#                       Count
# Age_Group fraudulent
# Adult     Yes           194
# Senior    Yes            12
# Youth     Yes            39

# %%
Fraud_ClaimsGroup.plot(kind='bar',ylabel='Count',title='Fraudulent Claims according to Age Group',figsize=(15,5),fontsize=20)
# Out:
# <AxesSubplot:title={'center':'Fraudulent Claims according to Age Group'}, xlabel='Age_Group,fraudulent', ylabel='Count'>

# %% [markdown]
# ### 14. Visualize the monthly trend of the total amount that has been claimed by the customers.
# ### Ensure that on the “month” axis, the month is in a chronological order not alphabetical order.

# %%
Cust_Claims['Month']=Cust_Claims.claim_date.apply(lambda x:pd.Timestamp.strftime(x,format='%m'))

# %%
Cust_Claims['Year']=Cust_Claims['claim_date'].dt.year

# %%
Month_Claim=Cust_Claims.groupby(['Year','Month'])[['claim_amount']].sum()

Month_Claim=Month_Claim.sort_values(by=['Year','Month'],ascending=[True,True])
Month_Claim
# Out:
#              claim_amount
# Year Month
# 2017 01     608015.468904
#      02     631455.979269
#      03     615575.979269
#      04     749415.489635
#      05     546740.968904
#      06     560143.489635
#      07     790867.958539
#      08     431615.979269
#      09     459467.427443
#      10     608988.468904
#      11     601186.979269
#      12     694252.489635
# 2018 01     719153.458539
#      02     533085.479269
#      03     704672.968904
#      04     544537.989635
#      05     567718.448174
#      06     717205.448174
#      07     588445.948174
#      08     479680.489635
#      09     523730.468904
#      10     800648.448174

# %%
Month_Claim.plot(kind='bar',ylabel='Amount',xlabel='Year-Month',title='Monthly Claim Amount Trend',figsize=(15,8),fontsize=15)
plt.show()

# %% [markdown]
# ### 15. What is the average claim amount for gender and age categories and suitably represent the above using
# ### a facetted bar chart, one facet that represents fraudulent claims and the other for non-fraudulent claims.

# %%
Avg_claim=pd.pivot_table(data=Cust_Claims,index=["Age_Group","gender"],columns=['fraudulent'],
                                       values='claim_amount',aggfunc='mean')
Avg_claim
# Out:
# fraudulent                  No           Yes
# Age_Group gender
# Adult     Female  12122.306252  12199.746714
#           Male    12305.975968  15747.044826
# Senior    Female  13782.965511   4387.888889
#           Male    13766.190476  28232.500000
# Youth     Female  13174.536397   9220.450407
#           Male    12089.533384   7799.610535

# %%
claim_amount_gender_age.plot(kind='bar',stacked=True,ylabel='Amount',figsize=(15,8),fontsize=14)
plt.show()

# %% [markdown]
# ### Based on the conclusions from exploratory analysis as well as suitable statistical tests, answer the below questions.
# ### Please include a detailed write-up on the parameters taken into consideration, the Hypothesis
# ### testing steps, conclusion from the p-values and the business implications of the statements.

# %% [markdown]
# ### 16. Is there any similarity in the amount claimed by males and females?

# %% [markdown]
# #### Hypothesis defined and Test used:

# %% [raw]
# H0(Null-Hypothesis) : There is similarity between the amount claimed by males and females.
#
# Ha(Alternate Hypothesis): There is a difference between the amount claimed by males and females.
#
# Confidence Level : 95 %
# If p_value < 0.05, to reject Null Hypothesis
#
# Type of Test: Independent sample t-test

# %%
Claims_byMale=Cust_Claims['claim_amount'].loc[Cust_Claims['gender']=='Male']
Claims_byFemale=Cust_Claims['claim_amount'].loc[Cust_Claims['gender']=='Female']

# %%
Claims_byMale.mean()
# Out:
# 12884.829631308425

# %%
Claims_byFemale.mean()
# Out:
# 12100.692029236623

# %%
Ind_Test=stats.ttest_ind(a=Claims_byMale,b=Claims_byFemale)
Ind_Test
# Out:
# Ttest_indResult(statistic=0.9630529881732577, pvalue=0.3357373087404285)

# %% [markdown]
# #### Conclusion:

# %% [raw]
# Conclusion: As p-value > 0.05, we cannot reject Null-Hypothesis.
# Business Conclusion: This means, there is similarity between the amount claimed by males and females.

# %% [markdown]
# ### 17. Is there any relationship between age category and segment?

# %% [markdown]
# ##### Hypothesis defined and Test used:

# %% [raw]
# H0(Null-Hypothesis) : There is a Relationship between age category and segment
#
# Ha(Alternate Hypothesis):  There is no Relationship between age category and segment
#
# Confidence Level : 95 %
# If p_value < 0.05, to reject Null Hypothesis
#
# Type of Test: Chi-Square Test

# %%
Segment_Agegroup=pd.crosstab(Cust_Claims['Age_Group'],Cust_Claims['Segment'],margins=True)
Segment_Agegroup
# Out:
# Segment    Gold  Platinum  Silver   All
# Age_Group
# Adult       285       275     261   821
# Senior       15        17      17    49
# Youth        71        69      68   208
# All         371       361     346  1078

# %%
Chi_Test=stats.chi2_contingency(Segment_Agegroup)
Chi_Test
# Out:
# (0.40933704825647454,
#  0.9999871661088807,
#  9,
#  array([[ 282.55194805,  274.93599258,  263.51205937,  821.        ],
#         [  16.86363636,   16.40909091,   15.72727273,   49.        ],
#         [  71.58441558,   69.65491651,   66.7606679 ,  208.        ],
#         [ 371.        ,  361.        ,  346.        , 1078.        ]]))

# %%
Chi_statisticsvalue=Chi_Test[0]
Chi_statisticsvalue
# Out:
# 0.40933704825647454

# %%
p_value=Chi_Test[1]
p_value
# Out:
# 0.9999871661088807

# %% [markdown]
# #### Conclusion:

# %% [raw]
# Conclusion: As p-value > 0.05, we cannot reject Null-Hypothesis.
# Business Conclusion: There is a relationship between Age Group and Segments

# %% [markdown]
# ### 18. The current year has shown a significant rise in claim amounts as compared to 2016-17 fiscal average which was $10,000.

# %% [markdown]
# #### Hpothesis Defined & Test Used:

# %% [raw]
# H0(Null-Hypothesis) : There is a no rise in claim amounts.
#
# Ha(Alternate Hypothesis):  There is a rise in claim amounts.
#
# Confidence Level : 95 %
# If p_value < 0.05, to reject Null Hypothesis
#
# Type of Test: one-sample t-test

# %%
Claims_byYear=Cust_Claims.groupby(['Year'])[['claim_amount']].sum()
Claims_byYear
# Out:
#       claim_amount
# Year
# 2017  7.297727e+06
# 2018  6.178879e+06

# %%
Claim_by2018=Cust_Claims.claim_amount[Cust_Claims.Year==2018]
Claim_by2018
# Out:
# 1        2980.0
# 3        1950.0
# 7        2240.0
# 9       36810.0
# 10       1730.0
#          ...
# 1073     2730.0
# 1074    33330.0
# 1075     2780.0
# 1077     2290.0
# 1080     1770.0
# Name: claim_amount, Length: 484, dtype: float64

# %%
stats.ttest_1samp(Claim_by2018,10000)
# Out:
# Ttest_1sampResult(statistic=4.508441689457533, pvalue=8.205144389110108e-06)

# %% [markdown]
# #### Conclusion

# %% [raw]
# Conclusion: As P-value < 0.05, we can reject Null Hypothesis
# Business Conclusion: There is a rise in claim amounts in current fiscal year as compared to last.

# %% [markdown]
# ### 19. Is there any difference between age groups and insurance claims?

# %% [markdown]
# #### Hpothesis Define and Test used:

# %% [raw]
# H0(Null-Hypothesis) : No relationship between age groups and insurance claims.
#
# Ha(Alternate Hypothesis):  There is relationship between age groups and insurance claims.
#
# Confidence Level : 95 %
# If p_value < 0.05, to reject Null Hypothesis
#
# Type of Test: f-test

# %%
Age_Group1 = Cust_Claims['total_policy_claims'].loc[Cust_Claims['Age_Group']=="Adult"]
Age_Group2 = Cust_Claims['total_policy_claims'].loc[Cust_Claims['Age_Group']=="Youth"]
Age_Group3 = Cust_Claims['total_policy_claims'].loc[Cust_Claims['Age_Group']=="Senior"]

# %%
stats.f_oneway(Age_Group1,Age_Group2,Age_Group3)
# Out:
# F_onewayResult(statistic=0.4909560012774597, pvalue=0.6121781668608601)

# %% [markdown]
# #### Conclusion

# %% [raw]
# Conclusion: As P-value > 0.05, we cannot reject Null hypothesis.
# Business Conclusion: There is a relationship between Age groups and Insurance Claims.

# %% [markdown]
# ### 20. Is there any relationship between total number of policy claims and the claimed amount?

# %% [markdown]
# #### Hypothesis Defined & Test used:

# %% [raw]
# H0(Null-Hypothesis) : No relationship between Number of policy claims  and Claimed Amount.
#
# Ha(Alternate Hypothesis):  There is relationship between Number of policy claims  and Claimed Amount.
#
# Confidence Level : 95 %
# If p_value < 0.05, to reject Null Hypothesis
#
# Type of Test: f-test

# %%
Claim1 = Cust_Claims.loc[ Cust_Claims.total_policy_claims == 1.0, 'claim_amount' ]
Claim2 = Cust_Claims.loc[ Cust_Claims.total_policy_claims == 2.0, 'claim_amount' ]
Claim3 = Cust_Claims.loc[ Cust_Claims.total_policy_claims == 3.0, 'claim_amount' ]
Claim4 = Cust_Claims.loc[ Cust_Claims.total_policy_claims == 4.0, 'claim_amount' ]
Claim5 = Cust_Claims.loc[ Cust_Claims.total_policy_claims == 5.0, 'claim_amount' ]
Claim6 = Cust_Claims.loc[ Cust_Claims.total_policy_claims == 6.0, 'claim_amount' ]
Claim7 = Cust_Claims.loc[ Cust_Claims.total_policy_claims ==7.0, 'claim_amount' ]
Claim8 = Cust_Claims.loc[ Cust_Claims.total_policy_claims == 8.0, 'claim_amount' ]

# %%
stats.f_oneway(Claim1,Claim2,Claim3,Claim4,Claim5,Claim6,Claim7,Claim8)
# Out:
# F_onewayResult(statistic=0.8380177570397658, pvalue=0.5557451472367814)

# %% [markdown]
# #### Conclusion:

# %% [raw]
# Conclusion: As p_value > 0.05, we cannot reject Null Hypothesis.
# Business Conclusion: There is no relationship between Number of policy claims and Claimed amount.

# %% [markdown]
# # FINISH
